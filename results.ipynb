# %%
import os
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
from tabulate import tabulate

results = pd.read_csv("/home/chris/Programming Projects/ATCS/Unit 03/Labs/SetAndMapRacing/data.csv")
results['name'] = results['name'].str.replace('03-sets-maps-searching-submissions/', '', regex=False)
results['name'] = results['name'].str.replace('03-sets-maps-searching-', '', regex=False)
results['name'] = results['name'].str.replace('00-', '', regex=False)
results = results.sort_values(by='all')
print(tabulate(results, headers='keys',tablefmt="pretty", showindex=False))
# Out:
# +-------------+----------+----------+----------+
# |    name     |   set    |   map    |   all    |
# +-------------+----------+----------+----------+
# |  McKibben   | 2192500  | 1766453  | 1979476  |
# |  Darsh1222  | 4447014  | 4568391  | 4507702  |
# |   Jcai972   | 5169847  | 4109081  | 4639464  |
# | ArcticRust  | 5045461  | 5231419  | 5138440  |
# | DevonParikh | 4419810  | 7079129  | 5749469  |
# |   BigGlu    | 13386250 | 29985452 | 21685851 |
# +-------------+----------+----------+----------+
